# %% [markdown]
# # Boltz Generalized Covalent Residue Modification
#
# Modifies the Boltz Chemical Component Dictionary cache with a new entry corresponding to an arbitrary covalent modification of a residue.
#
# ___
# <I>Benjamin Fry (bfry@g.harvard.edu)</I>

# %%
from rdkit import Chem
from rdkit.Chem import AllChem

import pickle
from pathlib import Path

# THIS IS ABSOLUTELY NECESSARY TO MAKE SURE THAT ALL PROPERTIES ARE PICKLED OR ELSE BOLTZ WILL CRASH.
Chem.SetDefaultPickleProperties(Chem.PropertyPickleOptions.AllProps)

# %%
ncaa_smiles_str = "O=C(CCSC[C@H](C(O)=O)N)N1CC(C(F)/C(OC)=C(OC)/OC)OC(OC)C1C2=NC=CC2"

# I'm not sure if this matters as long as it can be substructure matched into the covalent ligand, 
#   using an alanine might allow this to generalize beyond cysteine modifications and it seems to work in my testing.
#   You'd probably want to use the largest residue that matches the covalent attachment point to avoid matching to the wrong part of the ligand.
reference_residue_to_modify = 'CYS' 

# The new CCD code for the covalent ligand, the first 5 letters are written to the CIF file as the resname.
output_ccd_code = "CUSTOM"

# %% [markdown]
# ### Load the Boltz Cache Chemical Component Dictionary

# %%
cache_dir = Path("/nfs/polizzi/bfry/.boltz/")

ccd_path = cache_dir / 'ccd.pkl'
with ccd_path.open("rb") as file:
    ccd = pickle.load(file)  # noqa: S301

# %% [markdown]
# ### Visualize molecule and atom indices for sanity check

# %%
# Create drawing options with atom indices 
smiles_mol = Chem.MolFromSmiles(ncaa_smiles_str)
draw_options = Chem.Draw.MolDrawOptions()
draw_options.addAtomIndices = True  # Enable atom indices to be displayed

# Increase size of displayed image
import IPython.display
IPython.display.display(Chem.Draw.MolToImage(smiles_mol, size=(750, 750), options=draw_options))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=750x750>

# %%
# Load Cysteine from the CCD and remove hydrogens
cys_mol = ccd[reference_residue_to_modify]
reference_cys_mol = AllChem.RemoveHs(cys_mol)

# Search for the cysteine substructure in the ncaa molecule
has_match = smiles_mol.HasSubstructMatch(reference_cys_mol)
if has_match:
    match_indices = smiles_mol.GetSubstructMatch(reference_cys_mol)
    substruct_to_match = {i.GetProp('name'): match_indices[idx] for idx, i in enumerate(reference_cys_mol.GetAtoms())}

# Construct mapping of cysteine atom name to atom index in the ncaa molecule
idx_to_name = {j: i for i, j in substruct_to_match.items()}
idx_to_name
# Out:
# {10: 'N', 6: 'CA', 7: 'C', 9: 'O', 5: 'CB', 4: 'SG', 8: 'OXT'}

# %% [markdown]
# ### Add the metadata boltz expects to the atoms

# %%
for idx, atom in enumerate(smiles_mol.GetAtoms()):
    default_name = f'{atom.GetSymbol()}{str(atom.GetIdx())}'

    # If the index is a canonical cysteine atom, use the cysteine atom name
    name = idx_to_name.get(idx, default_name)

    # Set atom properties
    atom.SetProp('name', name)
    atom.SetProp('alt_name', name) 
    is_leaving = False
    if name == 'OXT':
        is_leaving = True
    atom.SetBoolProp('leaving_atom', is_leaving)

# %% [markdown]
# ### Reorder atoms to canonical ordering (N, Ca, C, O, CB, S, ...)

# %%
# Map atom name to atom index in the ncaa molecule 
curr_atom_order = {atom.GetProp('name'): idx for idx, atom in enumerate(smiles_mol.GetAtoms()) if atom.GetSymbol() != 'H'}

# Map atom name to atom index in the reference cysteine molecule
target_atom_order = {}
for atom in reference_cys_mol.GetAtoms():
    if atom.GetSymbol() == 'H':
        continue
    target_atom_order[atom.GetProp('name')] = atom.GetIdx()

# There are atoms not in target_atom_order that are in curr_atom_order so we need to these
remapped_atom_order = {}
offset_idx = len(target_atom_order)
for atom in curr_atom_order:
    if atom in target_atom_order:
        remapped_atom_order[atom] = target_atom_order[atom]
    else:
        remapped_atom_order[atom] = offset_idx
        offset_idx += 1

# Remove hydrogens and reorder atoms according to the order in the reference cysteine.
trim = AllChem.RemoveHs(smiles_mol)
remap_order = {x.GetProp('name'): (remapped_atom_order[x.GetProp('name')], x.GetIdx()) for x in trim.GetAtoms()}
remap_idx_list = [x[1] for x in sorted(remap_order.values())]
trim_reordered = Chem.RenumberAtoms(trim, remap_idx_list)

# %% [markdown]
# ### Generate a conformer, could make this more sophisticated...

# %%
# Generate a simple conformer, might want to do something more sophisticated or start with a DFT conformer in an SDF file.
trim_reordered = AllChem.AddHs(trim_reordered)
AllChem.EmbedMolecule(trim_reordered)
AllChem.UFFOptimizeMolecule(trim_reordered)

# Set conformer properties
for c in trim_reordered.GetConformers():
    c.SetProp('name', 'Ideal')

# %% [markdown]
# ### Sanity check renumbering was successful.

# %%
for atom in trim_reordered.GetAtoms():
    if atom.GetSymbol() == 'H':
        continue
    print(atom.GetIdx(), atom.GetPropsAsDict())
# Out:
# 0 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'N', 'alt_name': 'N', 'leaving_atom': False}
# 1 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, '_ChiralityPossible': 1, '_CIPCode': 'S', 'name': 'CA', 'alt_name': 'CA', 'leaving_atom': False}
# 2 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C', 'alt_name': 'C', 'leaving_atom': False}
# 3 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O', 'alt_name': 'O', 'leaving_atom': False}
# 4 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'CB', 'alt_name': 'CB', 'leaving_atom': False}
# 5 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'SG', 'alt_name': 'SG', 'leaving_atom': False}
# 6 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'OXT', 'alt_name': 'OXT', 'leaving_atom': True}
# 7 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O0', 'alt_name': 'O0', 'leaving_atom': False}
# 8 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C1', 'alt_name': 'C1', 'leaving_atom': False}
# 9 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C2', 'alt_name': 'C2', 'leaving_atom': False}
# 10 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C3', 'alt_name': 'C3', 'leaving_atom': False}
# 11 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'N11', 'alt_name': 'N11', 'leaving_atom': False}
# 12 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C12', 'alt_name': 'C12', 'leaving_atom': False}
# 13 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, '_ChiralityPossible': 1, 'name': 'C13', 'alt_name': 'C13', 'leaving_atom': False}
# 14 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, '_ChiralityPossible': 1, 'name': 'C14', 'alt_name': 'C14', 'leaving_atom': False}
# 15 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'F15', 'alt_name': 'F15', 'leaving_atom': False}
# 16 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C16', 'alt_name': 'C16', 'leaving_atom': False}
# 17 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O17', 'alt_name': 'O17', 'leaving_atom': False}
# 18 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C18', 'alt_name': 'C18', 'leaving_atom': False}
# 19 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C19', 'alt_name': 'C19', 'leaving_atom': False}
# 20 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O20', 'alt_name': 'O20', 'leaving_atom': False}
# 21 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C21', 'alt_name': 'C21', 'leaving_atom': False}
# 22 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O22', 'alt_name': 'O22', 'leaving_atom': False}
# 23 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C23', 'alt_name': 'C23', 'leaving_atom': False}
# 24 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O24', 'alt_name': 'O24', 'leaving_atom': False}
# 25 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, '_ChiralityPossible': 1, 'name': 'C25', 'alt_name': 'C25', 'leaving_atom': False}
# 26 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'O26', 'alt_name': 'O26', 'leaving_atom': False}
# 27 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C27', 'alt_name': 'C27', 'leaving_atom': False}
# 28 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, '_ChiralityPossible': 1, 'name': 'C28', 'alt_name': 'C28', 'leaving_atom': False}
# 29 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C29', 'alt_name': 'C29', 'leaving_atom': False}
# 30 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'N30', 'alt_name': 'N30', 'leaving_atom': False}
# 31 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C31', 'alt_name': 'C31', 'leaving_atom': False}
# 32 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C32', 'alt_name': 'C32', 'leaving_atom': False}
# 33 {'__computedProps': <rdkit.rdBase._vectSs object at 0x7f3303133040>, 'name': 'C33', 'alt_name': 'C33', 'leaving_atom': False}

# %% [markdown]
# ### Save the conformer to the ccd cache and overwrite it.

# %%
ccd[output_ccd_code] = trim_reordered

ccd_path = cache_dir / 'ccd.pkl'
with ccd_path.open("wb") as file:
    pickle.dump(ccd, file)

# %% [markdown]
# ### To Run Inference:
# Run `boltz predict ./path_to_yaml_file` with the following yaml file contents to test the custom modification at residue 2:
# ___
#
#
# ```yaml
# version: 1  # Optional, defaults to 1
# sequences:
#   - protein:
#       id: [A]
#       sequence: AAAAACAAAAAAAAAAA # This doesn't have to have a CYS at position 6 to apply the modification, but it does in this case.
#       msa: empty
#       modifications:
#         - position: 6
#           ccd: 'CUSTOM' # Use the custom CCD code we just injected.
# ```
